# %% [markdown]
# https://colab.research.google.com/drive/1LK0wBjejjD_1yHLfb0rvjPeF85kYip-L?usp=sharing

# %% [markdown]
# # LOAD DATA GROUP INTERNATIONAL

# %%
# 1 First we import and load all basic libraries

import pandas as pd                # For dataframe handling
import numpy as np                 # For matrix and list computations
import matplotlib.pyplot as plt    # For advanced graphs
from locale import normalize       # For computing proportions

# %%
# 2 Upload manually your excel document to Colab file system (left panel) and CONFIRM that your Excel file is in teh folder
# You shopuld do this step in every session.
# Aafter closing the session, the files will be erased from your Colab environment

# %%
# 3 Read the Excel Dataset and store it in an object  (you can name it at your will)
wbr = pd.read_excel ('/content/wbr_data.xlsx') #Your path to file here

# And make a quick previev
wbr
# Out:
#      instant     dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1 2011-01-01       1   0     1        0        6           0
# 1          2 2011-01-02       1   0     1        0        0           0
# 2          3 2011-01-03       1   0     1        0        1           1
# 3          4 2011-01-04       1   0     1        0        2           1
# 4          5 2011-01-05       1   0     1        0        3           1
# ..       ...        ...     ...  ..   ...      ...      ...         ...
# 726      727 2012-12-27       1   1    12        0        4           1
# 727      728 2012-12-28       1   1    12        0        5           1
# 728      729 2012-12-29       1   1    12        0        6           0
# 729      730 2012-12-30       1   1    12        0        0           0
# 730      731 2012-12-31       1   1    12        0        1           1
#
#     weathersit  temp_celsius  windspeed_kh     atemp      hum  casual  \
# ...

# %% [markdown]
# # Describe a nominal variable:
#
#
# *   Percentage table
# *   Bargraph

# %%
table1 = wbr.workingday.value_counts(normalize=True)*100
print(mytable)


print (mytable.sum())
# Out:
# workingday
# 1    68.399453
# 0    31.600547
# Name: proportion, dtype: float64
# 100.00000000000001

# %%
table1.plot(kind='bar')
# Out:
# <Axes: xlabel='workingday'>

# %%
# Improved bargraph
table1.plot(kind='bar',
              edgecolor='black',
            title='Figure 1: Pecentage of weather situation',
            ylabel='Percentage',
            xlabel='',
            rot=0)
plt.text (2,60, 'n=731')
# Out:
# Text(2, 60, 'n=731')

# %%
wbr.workingday.value_counts().sum()
# Out:
# 731
